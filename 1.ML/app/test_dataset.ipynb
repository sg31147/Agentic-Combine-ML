# %%
import pandas as pd
t1 = pd.read_feather('../1.ML/experiments/8fdtxcm4'+'/predictions_test.feather')
t2 = pd.read_feather('../1.ML/dataset/mimiciv/note/discharge.feather')

# Perform the join
merged_table = t1.merge(t2, left_on='_id', right_on='hadm_id', how='inner')

# Display the merged table
merged_table=merged_table[['_id','text','target']]

# %%
merged_table.to_csv('test_dataset.csv', index=False)
